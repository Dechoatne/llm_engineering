# %%
# imports

from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# %%
# Connect to Ollama's OpenAI-compatible local server
ollama = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"  # required by SDK, ignored by Ollama
)

# The local model to use — make sure you have pulled it: ollama pull llama3.2
MODEL = "llama3.2"

# Quick sanity check
test = ollama.chat.completions.create(
    model=MODEL,
    messages=[{"role": "user", "content": "Say 'Ollama is ready\!' and nothing else."}]
)
print(test.choices[0].message.content)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\!'
# <>:13: SyntaxWarning: invalid escape sequence '\!'
# /var/folders/32/fdngh_l52yd4cpmdpm6c4_000000gn/T/ipykernel_31386/4172153774.py:13: SyntaxWarning: invalid escape sequence '\!'
#   messages=[{"role": "user", "content": "Say 'Ollama is ready\!' and nothing else."}]
# Ollama is ready!

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
def summarize(url):
    """Fetch a website and summarize it using Ollama."""
    website = fetch_website_contents(url)
    response = ollama.chat.completions.create(
        model=MODEL,
        messages=messages_for(website)
    )
    return response.choices[0].message.content


def display_summary(url):
    """Fetch, summarize, and display a website summary as Markdown."""
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://cnn.com")
# Out:
# **Summary:** A website with a bunch of random links and text that seems to be a jumbled mess from CNN's homepage. It appears they've just copied their navigation menus onto this page.
#
# **News/Announcements:**
#
# * The website is experiencing technical issues, causing video playback problems when ads are present.
# * Users have reported various ad-related frustrations, such as slow loading, audio being too loud, and inability to access content due to ads.
# * Some users did not receive a thank you for providing feedback on the ads.

# %%
display_summary("https://anthropic.com")
# Out:
# **Anthropic's Mysterious Existence**
# A public benefit corporation trying to secure the good and mitigate the bad of AI, because we're all just a little too excited about robots taking over.
#
# **AI Research and Releases:**
# The largest study about people's desires for AI is out now! Apparently 81,000 people want safe AI. Meanwhile, Anthropic released Claude Opus 4.6, their strongest model yet...good luck making that thing work without crashing the entire robot rebellion

# %%
display_summary("https://edwarddonner.com")
# Out:
# # AI Enthusiast's Corner
#
# Edward Donner is a self-proclaimed LLM aficionado and aspiring writer. He co-founded Nebula.io, an AI startup that aims to empower people in discovering their potential. Donner created popular Udemy courses on AI and has been fascinated by Large Language Models (LLMs). On this site, he shares resources, news, and musings about his projects, including the competitive arena Outsmart and AI curriculum.
#
# # News & Announcements
#
# * February 17, 2026: "Vibe Coder to Agentic Engineer Resources Released"
# * January 4, 2026: "Create Agents with n8n - Latest AI Resources"
# * September 15, 2025: "Announce AI Engineering MLOps Track and Deployment Resources"
